# %%
import pandas as pd
from textblob import TextBlob
from langdetect import detect
import time

# %%
df = pd.read_csv('Data/typhoon.csv')

# %%
df
# Out:
#      Unnamed: 0      screen_name               username              user_id  \
# 0             0         yujii136                  松永　勇士           3068813443
# 1             1      InstBirdPop       Bird Populations           2835276254
# 2             2  imprezafujiwara  IMPRESA FUJIWARA(完全体)           2221172438
# 3             3     typhoon_aegi               台風喘ぎ声bot           2735296722
# 4             4      rooster_irl         Rooster Gaijin            301884812
# ..          ...              ...                    ...                  ...
# 369         369  jamesdeclearagh                  James  1213597279103250432
# 370         370       saeransbff                   dina  1284790526538121216
# 371         371         Ewing619               Ewing619             17168309
# 372         372          couzels           Katie Harmer            189653298
# 373         373       YutuTheFox  Typhoon Yutu (Rosita)           2971703092
#
# ...

# %%
df = df[df.text.str.len() > 50]

# %%
df
# Out:
#      Unnamed: 0      screen_name               username              user_id  \
# 0             0         yujii136                  松永　勇士           3068813443
# 1             1      InstBirdPop       Bird Populations           2835276254
# 2             2  imprezafujiwara  IMPRESA FUJIWARA(完全体)           2221172438
# 4             4      rooster_irl         Rooster Gaijin            301884812
# 5             5        Give2Asia              Give2Asia             15070427
# ..          ...              ...                    ...                  ...
# 366         366        hiimcubes                  cubes  1094841059161473025
# 368         368       MentalHeck          NEŌ WAX BLOOM           4889811585
# 369         369  jamesdeclearagh                  James  1213597279103250432
# 370         370       saeransbff                   dina  1284790526538121216
# 371         371         Ewing619               Ewing619             17168309
#
# ...

# %%
import langid
# langid.classify("猫が怖がりつつ全力で台風を楽しんでいる動画　- the cat enjoys typhoon...	")

# %%
from langid.langid import LanguageIdentifier, model
identifier = LanguageIdentifier.from_modelstring(model, norm_probs=True)
# y = identifier.classify("猫が怖がりつつ全力で台風を楽しんでいる動画　- the cat enjoys typhoon...	")
# print(y[0])
# identifier.classify("dedar")

# %%
df['lang'] = df['text'].apply(lambda x: identifier.classify(x)[0])

# %%
df
# Out:
#      Unnamed: 0      screen_name               username              user_id  \
# 0             0         yujii136                  松永　勇士           3068813443
# 1             1      InstBirdPop       Bird Populations           2835276254
# 2             2  imprezafujiwara  IMPRESA FUJIWARA(完全体)           2221172438
# 4             4      rooster_irl         Rooster Gaijin            301884812
# 5             5        Give2Asia              Give2Asia             15070427
# ..          ...              ...                    ...                  ...
# 366         366        hiimcubes                  cubes  1094841059161473025
# 368         368       MentalHeck          NEŌ WAX BLOOM           4889811585
# 369         369  jamesdeclearagh                  James  1213597279103250432
# 370         370       saeransbff                   dina  1284790526538121216
# 371         371         Ewing619               Ewing619             17168309
#
# ...

# %%
# df.to_csv('Data/typhoon_test.csv')
df = df[df.lang == 'en']

# %%
df
# Out:
#      Unnamed: 0      screen_name               username              user_id  \
# 0             0         yujii136                  松永　勇士           3068813443
# 1             1      InstBirdPop       Bird Populations           2835276254
# 2             2  imprezafujiwara  IMPRESA FUJIWARA(完全体)           2221172438
# 4             4      rooster_irl         Rooster Gaijin            301884812
# 5             5        Give2Asia              Give2Asia             15070427
# ..          ...              ...                    ...                  ...
# 366         366        hiimcubes                  cubes  1094841059161473025
# 368         368       MentalHeck          NEŌ WAX BLOOM           4889811585
# 369         369  jamesdeclearagh                  James  1213597279103250432
# 370         370       saeransbff                   dina  1284790526538121216
# 371         371         Ewing619               Ewing619             17168309
#
# ...
